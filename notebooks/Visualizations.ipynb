# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataDir = "../data/"
df = pd.read_csv(dataDir + "regression_data.csv")
df.head()
# Out:
#    fips     day_1     day_2     day_3     day_4     day_5     day_6     day_7  \
# 0  1001  0.000000  0.000000  0.000000  0.154151  0.000000  0.356675  0.000000
# 1  1003  0.405465  0.182322  0.054067  0.233615  0.080043  0.109199  0.033902
# 2  1005  0.251314  0.105361  0.000000  0.000000  0.095310  0.167054  0.074108
# 3  1007  0.000000  0.133531  0.117783  0.200671  0.000000  0.167054  0.207639
# 4  1009  0.405465  0.105361  0.000000  0.000000  0.000000  0.000000  0.095310
#
#       day_8     day_9  ...  educational services  \
# 0  0.182322  0.000000  ...              0.024400
# 1  0.154151  0.108214  ...              0.020718
# 2  0.068993  0.182322  ...              0.000000
# 3  0.060625  0.000000  ...              0.014769
# 4  0.087011  0.000000  ...              0.000000
#
#    health care and social assistance  arts, entertainment, and recreation  \
# 0                           0.087221                             0.026939
# ...

# %%
df = df[["density", 
         "administrative and support and waste management and remediation services",
         "transportation and warehousing", 
         "wholesale trade",
         "manufacturing"]]
df = df.replace(to_replace=float(0), value=np.nan)
admin = df["administrative and support and waste management and remediation services"]
trans = df["transportation and warehousing"]
whole = df["wholesale trade"]
manu = df["manufacturing"]

# %%
sns.set(style="darkgrid")
fig = plt.figure(figsize=(10, 10))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
ax = fig.add_subplot(2, 2, 1)
sns.scatterplot(x='density',y="administrative and support and waste management and remediation services", data=df)
plt.hlines(admin.mean(), 0, 20000)
plt.hlines([admin.mean() + admin.std(), admin.mean() - admin.std()], 0, 20000,
           color = 'r', linestyle='--')
ax.set(ylabel='administrative')
ax = fig.add_subplot(2, 2, 2)
sns.scatterplot(x='density',y='transportation and warehousing', data=df)
plt.hlines(trans.mean(), 0, 20000)
plt.hlines([trans.mean() + admin.std(), trans.mean() - trans.std()], 0, 20000,
           color = 'r', linestyle='--')
ax = fig.add_subplot(2, 2, 3)
sns.scatterplot(x='density',y="wholesale trade", data=df)
plt.hlines(whole.mean(), 0, 20000)
plt.hlines([whole.mean() + whole.std(), whole.mean() - whole.std()], 0, 20000,
           color = 'r', linestyle='--')
ax = fig.add_subplot(2, 2, 4)
sns.scatterplot(x='density',y="manufacturing", data=df)
plt.hlines(manu.mean(), 0, 20000)
plt.hlines([manu.mean() + manu.std(), manu.mean() - manu.std()], 0, 20000,
           color = 'r', linestyle='--')
plt.show()

# %%
from sklearn import preprocessing
# Get column names first
names = df.columns
# Create the Scaler object
scaler = preprocessing.StandardScaler()
# Fit your data on the scaler object
sdf = scaler.fit_transform(df)
sdf = pd.DataFrame(scaled_df, columns=names)
sdf
# Out:
#        density  \
# 0    -0.178000
# 1    -0.127745
# 2    -0.253394
# 3    -0.244334
# 4    -0.182415
# ...        ...
# 2438 -0.271996
# 2439 -0.281042
# 2440 -0.279143
# 2441 -0.274560
# 2442 -0.281741
#
#       administrative and support and waste management and remediation services  \
# 0                                                   NaN
# 1                                              0.680773
# 2                                             -0.025816
# 3                                             -0.025816
# 4                                             -0.025816
# ...                                                 ...
# 2438                                          -0.752607
# 2439                                          -0.846104
# 2440                                          -0.197005
# 2441                                          -1.174546
# 2442                                          -1.174546
#
# ...

# %%
import statsmodels.api as sm
from scipy.stats import norm
import pylab

sm.qqplot(sdf['administrative and support and waste management and remediation services'], line='45')
pylab.show()

# %%
fig = plt.figure(figsize=(10, 10))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
ax = fig.add_subplot(2, 2, 1)
sns.distplot(sdf['administrative and support and waste management and remediation services'])
ax.set(xlabel='administrative')
ax = fig.add_subplot(2, 2, 2)
sns.distplot(sdf['transportation and warehousing'])
ax = fig.add_subplot(2, 2, 3)
sns.distplot(sdf['wholesale trade'])
ax = fig.add_subplot(2, 2, 4)
sns.distplot(sdf['manufacturing'])
plt.show()
